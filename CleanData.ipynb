# %% [markdown]
# # Clean raw log & feature engineering

# %% [markdown]
# ## This part will clean and formart the raw log to DataFrame. And analysis the log data for feature selection

# %% [markdown]
# ### 1. fomart the whole raw log to json object , then flattern the data using pandas

# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import io

from pandas.io.json import json_normalize

# %%
with io.open('/Users/junyyan/tiger/DataShenCe/神策数据/sensorswww_data.json', "r", encoding="utf-8") as json_data:
    data = json.load(json_data)
    df = json_normalize(data)

# %%
list(df)
# Out:
# [u'_nocache',
#  u'distinct_id',
#  u'event',
#  u'jssdk_error',
#  u'lib.$lib',
#  u'lib.$lib_method',
#  u'lib.$lib_version',
#  u'properties.$browser',
#  u'properties.$browser_version',
#  u'properties.$first_browser_language',
#  u'properties.$first_referrer',
#  u'properties.$first_referrer_host',
#  u'properties.$first_visit_time',
#  u'properties.$ip',
#  u'properties.$is_first_day',
#  u'properties.$is_first_time',
#  u'properties.$latest_referrer',
#  u'properties.$latest_referrer_host',
#  u'properties.$latest_utm_campaign',
#  u'properties.$latest_utm_content',
#  u'properties.$latest_utm_medium',
#  u'properties.$latest_utm_source',
#  u'properties.$latest_utm_term',
#  u'properties.$lib',
#  u'properties.$lib_version',
#  u'properties.$model',
#  u'properties.$os',
#  u'properties.$os_version',
#  u'properties.$referrer',
#  u'properties.$referrer_host',
#  u'properties.$screen_height',
#  u'properties.$screen_width',
#  u'properties.$title',
#  u'properties.$url',
# ...

# %%
df.event.unique()
# Out:
# array([u'index_leave', nan, u'$pageview', u'btnClick', u'demo_leave',
#        u'click_send_cellphone', u'verify_cellphone_code', u'clickSubmit',
#        u'about_leave', u'courses_leave', u'formSubmit', u'page_close',
#        u'courses_play_leave'], dtype=object)

# %%
df.describe()

# %%
df.head(10)
# Out:
#         _nocache                               distinct_id        event  \
# 0  0654392402996  595466e9a8e733434ce08de16e927d985e0b5d48  index_leave
# 1  3040562711955  9939d3e087bca29c42334d96dccd25ca0e06652a          NaN
# 2  9587552771961  9939d3e087bca29c42334d96dccd25ca0e06652a    $pageview
# 3  0652937076129  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick
# 4  8207407748558  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick
# 5  4967393021929  595466e9a8e733434ce08de16e927d985e0b5d48   demo_leave
# 6  0382763295792  c98f9661c89faeedb1109065d146f5be806f2d50     btnClick
# 7  6250648113207  c98f9661c89faeedb1109065d146f5be806f2d50    $pageview
# 8  6907472183771  9939d3e087bca29c42334d96dccd25ca0e06652a     btnClick
# 9  1770400447899  978ab1876c3063608cd564a1ab90bfd6eaaf8e44     btnClick
#
#   jssdk_error lib.$lib lib.$lib_method lib.$lib_version properties.$browser  \
# 0         NaN       js            code           1.6.20              chrome
# ...

# %%
df.count()
# Out:
# _nocache                               75092
# distinct_id                            75092
# event                                  65673
# jssdk_error                               58
# lib.$lib                               75092
# lib.$lib_method                        75092
# lib.$lib_version                       75092
# properties.$browser                    65673
# properties.$browser_version            65673
# properties.$first_browser_language      9148
# properties.$first_referrer              9369
# properties.$first_referrer_host         9369
# properties.$first_visit_time            9419
# properties.$ip                         65673
# properties.$is_first_day               65673
# properties.$is_first_time              65673
# properties.$latest_referrer            64862
# properties.$latest_referrer_host       64862
# properties.$latest_utm_campaign        39903
# properties.$latest_utm_content         38763
# properties.$latest_utm_medium          39691
# ...

# %%
for col in df.columns:
# Out:
# Index([u'_nocache', u'distinct_id', u'event', u'jssdk_error', u'lib.$lib',
#        u'lib.$lib_method', u'lib.$lib_version', u'properties.$browser',
#        u'properties.$browser_version', u'properties.$first_browser_language',
#        u'properties.$first_referrer', u'properties.$first_referrer_host',
#        u'properties.$first_visit_time', u'properties.$ip',
#        u'properties.$is_first_day', u'properties.$is_first_time',
#        u'properties.$latest_referrer', u'properties.$latest_referrer_host',
#        u'properties.$latest_utm_campaign', u'properties.$latest_utm_content',
#        u'properties.$latest_utm_medium', u'properties.$latest_utm_source',
#        u'properties.$latest_utm_term', u'properties.$lib',
#        u'properties.$lib_version', u'properties.$model', u'properties.$os',
#        u'properties.$os_version', u'properties.$referrer',
#        u'properties.$referrer_host', u'properties.$screen_height',
# ...

# %%
rowsNum = df.shape[0]

# %%
naPercent = lambda x: round(x.isnull().sum()/rowsNum, 2)

# %%
df.isnull().sum()

# %%
df['properties.$browser_version']
# Out:
# 0          56
# 1         NaN
# 2          56
# 3          56
# 4          56
# 5          56
# 6          54
# 7          54
# 8          56
# 9          51
# 10         51
# 11         56
# 12         51
# 13        NaN
# 14         45
# 15         45
# 16         45
# 17         56
# 18        NaN
# 19        6.5
# 20        NaN
# 21          9
# 22         45
# 23         56
# 24         48
# 25         56
# 26         45
# 27         45
# 28         45
# 29         45
#          ...
# 75062      49
# 75063     NaN
# 75064      -1
# 75065      -1
# 75066      49
# 75067      -1
# 75068      49
# 75069      49
# 75070      49
# 75071      49
# 75072      35
# 75073      10
# 75074     NaN
# 75075     6.5
# 75076     NaN
# 75077      56
# 75078     NaN
# 75079      56
# 75080      56
# 75081      56
# 75082      56
# 75083      56
# 75084      56
# 75085      56
# 75086      56
# 75087     NaN
# 75088       8
# 75089     NaN
# 75090    11.4
# 75091     NaN
# ...

# %% [markdown]
# remove columns that is not related to the prediction:
# _nocache
